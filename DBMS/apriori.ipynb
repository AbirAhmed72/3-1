# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('D:\\Poralekha\\3-1\\DBMS\\apriori.csv')

# Print the data frame
print(df)

# %%
import pandas as pd

# Read the CSV file into a data frame, with the arrays separated by a comma
df = pd.DataFrame(pd.read_csv('D:\\Poralekha\\3-1\\DBMS\\apriori.csv', delimiter=', '))
# df[['Column1', 'Column2']] = df['ArrayColumn'].str.split(', ')

# Print the data frame
print(df)

transactions_dict = df.set_index("TID")["PRODUCTS"].to_dict()


# Remove the first element from the list
# del df[0]
# print(df)/////////////

# Create a dictionary from the data
# transactions_dict = {entry[0]: entry[1] for entry in df}

# # Print the dictionary
print(transactions_dict)
# Out:
#     "TID"                                 ["PRODUCTS"],
# 0   "TID1"                  ["MILK","BREAD","BISCUIT"],
# 1   "TID2"     ["BREAD","MILK","BISCUIT","CORNFLAKES"],
# 2   "TID3"                 ["BREAD","TEA","BOURNVITA"],
# 3   "TID4"              ["JAM","MAGGI","BREAD","MILK"],
# 4   "TID5"                   ["MAGGI","TEA","BISCUIT"],
# 5   "TID6"                 ["BREAD","TEA","BOURNVITA"],
# 6   "TID7"                ["MAGGI","TEA","CORNFLAKES"],
# 7   "TID8"           ["MAGGI","BREAD","TEA","BISCUIT"],
# 8   "TID9"               ["JAM","MAGGI","BREAD","TEA"],
# 9   "TID10"                           ["BREAD","MILK"],
# 10  "TID11"   ["COFFEE","COCK","BISCUIT","CORNFLAKES"],
# 11  "TID12"   ["COFFEE","COCK","BISCUIT","CORNFLAKES"],
# 12  "TID13"             ["COFFEE","SUGER","BOURNVITA"],
# 13  "TID14"                  ["BREAD","COFFEE","COCK"],
# 14  "TID15"                ["BREAD","SUGER","BISCUIT"],
# 15  "TID16"            ["COFFEE","SUGER","CORNFLAKES"],
# 16  "TID17"              ["BREAD","SUGER","BOURNVITA"],
# 17  "TID18"                 ["BREAD","COFFEE","SUGER"],
# 18  "TID19"                 ["BREAD","COFFEE","SUGER"],
# 19  "TID20"        ["TEA","MILK","COFFEE","CORNFLAKES"]
# C:\Users\Abir\AppData\Local\Temp\ipykernel_18004\3113379579.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.DataFrame(pd.read_csv('D:\\Poralekha\\3-1\\DBMS\\apriori.csv', delimiter=', '))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 10
#       5 # df[['Column1', 'Column2']] = df['ArrayColumn'].str.split(', ')
#       6
#       7 # Print the data frame
#       8 print(df)
# ---> 10 transactions_dict = df.set_index("TID")["PRODUCTS"].to_dict()
#      13 # Remove the first element from the list
#      14 # del df[0]
#      15 # print(df)/////////////
#    (...)
#      19
#      20 # # Print the dictionary
#      21 print(transactions_dict)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6006                 missing.append(col)
#    6008 if missing:
# -> 6009     raise KeyError(f"None of {missing} are in the columns")
#    6011 if inplace:
#    6012     frame = self
#
# KeyError: "None of ['TID'] are in the columns"
